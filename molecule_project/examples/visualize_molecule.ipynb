# %%
from molecules.molecule import Molecule
from molecules.visualize import show_molecule

# %%
# Load water molecule
mol = Molecule().from_xyz("water.xyz")
mol
# Out:
# Molecule with 3 atoms

# %%
# Visualize molecule as sticks
show_molecule(mol, style="stick")
# visualize as spheres
show_molecule(mol, style="sphere")
# Out:
# <div id="3dmolviewer_1762884372874849"  style="position: relative; width: 500px; height: 400px;">
#         <p id="3dmolwarning_1762884372874849" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...
